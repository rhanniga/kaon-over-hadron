# %%
import ROOT as rt
# Out:
# Welcome to JupyROOT 6.18/04

# %%
canvas = rt.TCanvas()
file = rt.TFile("trig_4_8_assoc_2_4_cent_0_20_mixcorr_hKaon.root")
new = file.Get("hKaon2Dpeak")

# %%
new.GetXaxis().SetRangeUser(-1.2, 1.2)
new.Draw("SURF1")
canvas.Draw()
